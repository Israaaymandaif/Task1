# %% [markdown]
#    <h1> Mini Project 1</h1>
#
# <h2>Statement:-</h2>
#       <h4>The task is to create an “Online Library Management System.”</h4>
#       <h4>For this, you have to create a library class that includes the</h4>
#       <h4>following methods:</h4>
#
# <h3>Displaybook(): To display the available books</h3>
# <h3>Lendbook(): To lend a book to a user</h3>
# <h3>Addbook(): To add a book to the library</h3>
# <h3>Returnbook(): To return the book to the library.</h3>
#
# <h4>As you have created a library class, now you will create an</h4>
#
# <h4>object and pass the following parameters in the constructor.</h4>
# <h3>HarryLibrary=Library(listofbooks, library_name)</h3>
#
# <h4>After that, create a main function and run an infinite while loop</h4>
# <h4>that asks the users for their input whether they want to display,lend, add or return a book.</h4>
#
# <h2>Optional:-</h2>
#
# <h3>Maintain a dictionary for the users who own a book. Dictionary
# should take book name as a key and name of the person as a
# value. Whenever you lend a book to a user, you should maintain
# a dictionary</h3>

# %%
class Mylibrary:
             #constructor
    def __init__ (self , listofbooks , nameofbook ):
        
              #Attributes
        self.listofbooks = listofbooks
        self.nameofbook = nameofbook
        self.lended=[]
        
        
        
#Funcation To display the available books
    def Displaybook(self): 
        
        for book in self.listofbooks :
            
            print (book)
            
            
#Funcation To lend a book to a user  
    def Lendbook(self): 
        
        lend_of_book=input("please enter the name of book  ")
        
        #checking if the book in listofbook       
        if lend_of_book in self.listofbooks:  
        
        #remove this book from listofbook
            self.listofbooks.remove(lend_of_book)
    
        #add this book to lendofbook
            self.lended.append(lend_of_book)
            
            print('you can lend your favourit book😊')
        
        else:
           
            print("I'am sorry, you can not lend your book  , It's not Found 😥!")
                  
                  
#Funcation To add a book to the library
    def Addbook(self):
                  
            #input your favourit book to add it 
                   add_book=input("please enter the name of book ")
                  
                  
            #add the book to listofbook
                   self.listofbooks.append(add_book)
                   print("the book is adding successfully😊")
   
#Funcation To return the book to the library.

    def Returnbook(self):
                  return_book=input("please enter the name of book  ")
                  
                
                #checking if the book in lendofbook
                  if return_book in self.lended :
                        
                #remove this book from lendofbook 
                        self.lended.remove(return_book)
        
                #add this book to listofbook 
                        self.listofbooks.append(return_book)                      
                       
                    
                        print("the book is returning successfully😊")
                  
                  else :
                        print("I'am sorry, you can not return your book  ,It Doesn't Belong This library 😥! ")

# %%
israa = Mylibrary(['Emotional Inteligence','Thinkin , Fast and Slow','The power Of Habit','Peresonality Psychology'],'garir')

def main ():
    
    while True:
        method = input('please enter  you want  Display, lend, Add or Return a book:')
        
        if method == 'Display':
            
            israa.Displaybook()
            
        elif method == 'lend':
            
            israa.Lendbook()
            
        elif method == 'Add':
            
            israa.Addbook()  
            
        elif method == 'Return':
            
            israa.Returnbook() 
            
        else:
            
            print("I'm sorry,this is method not available , you can try again😊")
            
            
if __name__=='__main__':
    main()
# Out:
# please enter  you want  Display, lend, Add or Return a book:Display
# Emotional Inteligence
# Thinkin , Fast and Slow
# The power Of Habit
# Peresonality Psychology
# please enter  you want  Display, lend, Add or Return a book:Lend
# I'm sorry,this is method not available , you can try again😊
# please enter  you want  Display, lend, Add or Return a book:lend
# please enter the name of book  The power Of Habit
# you can lend your favourit book😊
# please enter  you want  Display, lend, Add or Return a book:Add
# please enter the name of book My Life
# the book is adding successfully😊
# please enter  you want  Display, lend, Add or Return a book:Return
# please enter the name of book  The power Of Habit
# the book is returning successfully😊
# please enter  you want  Display, lend, Add or Return a book:Return
# please enter the name of book  Cyber Secuirty
# I'am sorry, you can not return your book  ,It Doesn't Belong This library 😥!
# ...
